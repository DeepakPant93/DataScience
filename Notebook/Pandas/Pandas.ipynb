# %%
# !pip install pandas #only one time process for jupyter notebook
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Invalid requirement: '#only'

# %%
import pandas as pd #every time you create a new jupyter notebook

# %%
#pandas- panel data analysis

# %%
#data structures in pandas
# series
#dataframe

# %%
#creating series

# %%
list1= ["a","b","c","d","e"]

# %%
series1 = pd.Series(list1)

# %%
series1
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
series2 = pd.Series(["a","p","p","l","e"])
series2
# Out:
# 0    a
# 1    p
# 2    p
# 3    l
# 4    e
# dtype: object

# %%
#dataframe

# %%
di1 ={"Name":["A","B","C"],"age":[32,33,41],"player_type":["batsman","batsman","batsman"]}

# %%
players = pd.DataFrame(di1)

# %%
players
# Out:
#   Name  age player_type
# 0    A   32     batsman
# 1    B   33     batsman
# 2    C   41     batsman

# %%
#defining your own index

# %%
series2= pd.Series(["a","b","c"], index=[101,102,103])
series2
# Out:
# 101    a
# 102    b
# 103    c
# dtype: object

# %%
#extracting a single column
players["age"]
# Out:
# 0    32
# 1    33
# 2    41
# Name: age, dtype: int64

# %%
#using iloc
#dataframe_name[start postion of row:end position  of row,start position of column:end position of column]
#give the index of rows and columns to extract data

players.iloc[0:2,0:2]
# Out:
#   Name  age
# 0    A   32
# 1    B   33

# %%
#using loc
#dataframe_name[[start postion of row,end position  of row], ["column names"]]

# %%
players.loc[[0,2],["Name","player_type"]]
# Out:
#   Name player_type
# 0    A     batsman
# 2    C     batsman

# %%
#loading a csv file with pandas

# %% [markdown]
# dataframe_name = pd.read_csv("filename.csv")

# %%
df = pd.read_csv("MovieData.csv")

# %%
df
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
#to see top rows

df.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# ...

# %%
df.head(2)
# Out:
#         Title  title_year     budget      Gross      actor_1_name  \
# 0  La La Land        2016   30000000  151101803      Ryan Gosling
# 1    Zootopia        2016  150000000  341268248  Ginnifer Goodwin
#
#     actor_2_name actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 0     Emma Stone   Amiée Conn                   14000                 19000.0
# 1  Jason Bateman   Idris Elba                    2800                 28000.0
#
#    actor_3_facebook_likes  ...  Votes3044M Votes3044F Votes45A Votes45AM  \
# 0                     NaN  ...         7.9        7.8      7.6       7.6
# 1                 27000.0  ...         7.8        8.1      7.8       7.8
#
#    Votes45AF  Votes1000  VotesUS  VotesnUS  content_rating  Country
# 0        7.5        7.1      8.3       8.1           PG-13      USA
# 1        8.1        7.6      8.0       8.0              PG      USA
#
# [2 rows x 62 columns]

# %%
#to see bottom rows
df.tail()
# Out:
#                                            Title  title_year     budget  \
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name     actor_2_name  \
# 95   13092000              J.K. Simmons  Melissa Benoist
# 96    8114507  Seamus Davey-Fitzpatrick     Ariane Labed
# 97  936662225               Doug Walker       Rob Walker
# 98  296347721              Rupert Grint       Toby Jones
# 99     223838            Katrina Bowden     Tyler Labine
#
#               actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 95            Chris Mulkey                   24000                   970.0
# ...

# %%
df.tail(3)
# Out:
#                                            Title  title_year     budget  \
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross    actor_1_name  actor_2_name    actor_3_name  \
# 97  936662225     Doug Walker    Rob Walker               0
# 98  296347721    Rupert Grint    Toby Jones    Alfred Enoch
# 99     223838  Katrina Bowden  Tyler Labine  Chelan Simmons
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 97                     131                    12.0                     0.0
# 98                   10000                  2000.0                  1000.0
# 99                     948                   779.0                   440.0
#
#     ...  Votes3044M Votes3044F Votes45A Votes45AM  Votes45AF  Votes1000  \
# ...

# %%
EDA: exploratory data analysis
# Out:
#   Cell In[28], line 1
#     EDA: exploratory data analysis
#                      ^
# SyntaxError: invalid syntax

# %%
#inspecting the data

# %%
#to view the shape of data i.e rows and columns in it
df.shape

# %%
df.size

# %%
df.info()

# %%
df

# %%
#set to display a specific number of rows and columns

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 62

# %%
df

# %%
pd.options.display.max_rows = 10
pd.options.display.max_columns = 62

# %%
df.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
#it returns the summary of all numerical columns. the column should be int or float

# %%
df.dtypes
# Out:
# Title              object
# title_year          int64
# budget              int64
# Gross               int64
# actor_1_name       object
#                    ...
# Votes1000         float64
# VotesUS           float64
# VotesnUS          float64
# content_rating     object
# Country            object
# Length: 62, dtype: object

# %%
#sorting the data

# %%
#let's sort the dataframe on the basis of budget

# %%
df_sorted= df.sort_values(by="budget")
#df.sort_values(by="budget", inplace= True) used to make permanent changes in dataframe

# %%
df_sorted
# Out:
#                                          Title  title_year     budget  \
# 96                             Before Midnight        2013    3000000
# 95                                    Whiplash        2014    3300000
# 94                                     Boyhood        2014    4000000
# 99                     Tucker and Dale vs Evil        2010    5000000
# 93                          Dallas Buyers Club        2013    5000000
# ..                                         ...         ...        ...
# 10         The Hobbit: The Desolation of Smaug        2013  225000000
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
# 9                   Captain America: Civil War        2016  250000000
# 8                        The Dark Knight Rises        2012  250000000
# 7                                      Tangled        2010  260000000
#
#         Gross              actor_1_name        actor_2_name  \
# 96    8114507  Seamus Davey-Fitzpatrick        Ariane Labed
# ...

# %%
df_sorted= df.sort_values(by="budget", ascending = False)

# %%
df_sorted
# Out:
#                                          Title  title_year     budget  \
# 7                                      Tangled        2010  260000000
# 8                        The Dark Knight Rises        2012  250000000
# 9                   Captain America: Civil War        2016  250000000
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
# 10         The Hobbit: The Desolation of Smaug        2013  225000000
# ..                                         ...         ...        ...
# 93                          Dallas Buyers Club        2013    5000000
# 99                     Tucker and Dale vs Evil        2010    5000000
# 94                                     Boyhood        2014    4000000
# 95                                    Whiplash        2014    3300000
# 96                             Before Midnight        2013    3000000
#
#         Gross              actor_1_name        actor_2_name  \
# 7   200807262              Brad Garrett        Donna Murphy
# ...

# %%
#sorting on multiple columns and in different orders
#this is known as multi level sorting

# %%
df_sorted= df.sort_values(by=["title_year","budget"])
df_sorted
# Out:
#                          Title  title_year     budget      Gross  \
# 99     Tucker and Dale vs Evil        2010    5000000     223838
# 83                  Black Swan        2010   13000000  106952327
# 82                     Flipped        2010   14000000    1752214
# 76           The King's Speech        2010   15000000  138795342
# 73                   127 Hours        2010   18000000   18329466
# ..                         ...         ...        ...        ...
# 3                      Arrival        2016   47000000  100546139
# 47                    Deadpool        2016   58000000  363024263
# 1                     Zootopia        2016  150000000  341268248
# 6               Doctor Strange        2016  165000000  232641920
# 9   Captain America: Civil War        2016  250000000  407197282
#
#             actor_1_name        actor_2_name     actor_3_name  \
# 99        Katrina Bowden        Tyler Labine   Chelan Simmons
# ...

# %%
df_sorted= df.sort_values(by=["title_year","budget"], ascending=[True, False])
df_sorted
# Out:
#                                            Title  title_year     budget  \
# 7                                        Tangled        2010  260000000
# 12                                   Toy Story 3        2010  200000000
# 24                      How to Train Your Dragon        2010  165000000
# 27                                     Inception        2010  160000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# ..                                           ...         ...        ...
# 3                                        Arrival        2016   47000000
# 0                                     La La Land        2016   30000000
# 2                                           Lion        2016   12000000
# 5                             Hell or High Water        2016   12000000
# 4                          Manchester by the Sea        2016    9000000
#
#         Gross       actor_1_name        actor_2_name          actor_3_name  \
# ...

# %%
df[["Title","title_year"]]
# Out:
#                                            Title  title_year
# 0                                     La La Land        2016
# 1                                       Zootopia        2016
# 2                                           Lion        2016
# 3                                        Arrival        2016
# 4                          Manchester by the Sea        2016
# ..                                           ...         ...
# 95                                      Whiplash        2014
# 96                               Before Midnight        2013
# 97    Star Wars: Episode VII - The Force Awakens        2015
# 98  Harry Potter and the Deathly Hallows: Part I        2010
# 99                       Tucker and Dale vs Evil        2010
#
# [100 rows x 2 columns]

# %%
#filtering the data by applying a logical condition
#or subsetting the data based on a specific condition

# %%
movies2016= df[df["title_year"]==2016]

# %%
movies2012= df[df["title_year"]==2012]

# %% [markdown]
# & - used for and operator <br>
# | - used for or operator <br>
# == equality check <br>
# != not equals to <br>
# > greater than<br>
# < less than<br>
# >= greater than or equals<br>
# <= less than or equals<br>

# %% [markdown]
# Using and/ or in conditions

# %%
#find the movies released in 2010 or 2012

# %%
df[(df["title_year"]==2012) | (df["title_year"]==2010)]
# Out:
#                                            Title  title_year     budget  \
# 7                                        Tangled        2010  260000000
# 8                          The Dark Knight Rises        2012  250000000
# 11                                  The Avengers        2012  220000000
# 12                                   Toy Story 3        2010  200000000
# 13                                       Skyfall        2012  200000000
# 16             The Hobbit: An Unexpected Journey        2012  180000000
# 24                      How to Train Your Dragon        2010  165000000
# 25                                Wreck-It Ralph        2012  165000000
# 27                                     Inception        2010  160000000
# 35                              Django Unchained        2012  100000000
# 40                                Shutter Island        2010   80000000
# 41                                 Despicable Me        2010   69000000
# ...

# %%
df[((df["title_year"]==2012) & (df["budget"]>220000000) )|]
# Out:
#                    Title  title_year     budget      Gross actor_1_name  \
# 8  The Dark Knight Rises        2012  250000000  448130642    Tom Hardy
#
#      actor_2_name          actor_3_name  actor_1_facebook_likes  \
# 8  Christian Bale  Joseph Gordon-Levitt                   27000
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# 8                 23000.0                 23000.0  ...         8.3        8.2
#
#   Votes45A Votes45AM  Votes45AF  Votes1000  VotesUS  VotesnUS  content_rating  \
# 8      7.9       7.9        7.9        7.8      8.4       8.4           PG-13
#
#    Country
# 8      USA
#
# [1 rows x 62 columns]

# %%
#finding the value count of a specific column

# %%
df.value_counts(["title_year"])
# Out:
# Country
# USA          81
# UK           11
# Australia     3
# France        3
# Canada        1
# Spain         1
# dtype: int64

# %%
#finding the unique values in different columns

# %%
df.nunique()
# Out:
# Title             100
# title_year          7
# budget             60
# Gross             100
# actor_1_name       75
#                  ...
# Votes1000          19
# VotesUS            13
# VotesnUS           13
# content_rating      4
# Country             6
# Length: 62, dtype: int64

# %%
#concatination of dataframes

# %%
#lets concatenate these two dataframes movies2012 movies2016

# %%
movies_2012_2016= pd.concat([movies2012,movies2016], axis=0)

# %%
movies_2012_2016_2= pd.concat([movies2012,movies2016], axis=1)
movies_2012_2016_2
# Out:
#                                 Title  title_year       budget        Gross  \
# 8               The Dark Knight Rises      2012.0  250000000.0  448130642.0
# 11                       The Avengers      2012.0  220000000.0  623279547.0
# 13                            Skyfall      2012.0  200000000.0  304360277.0
# 16  The Hobbit: An Unexpected Journey      2012.0  180000000.0  303001229.0
# 25                     Wreck-It Ralph      2012.0  165000000.0  189412677.0
# 35                   Django Unchained      2012.0  100000000.0  162804648.0
# 44                    Les MisÃ©rables      2012.0   61000000.0  148775460.0
# 51                               Argo      2012.0   44500000.0  136019448.0
# 68            Silver Linings Playbook      2012.0   21000000.0  132088910.0
# 75                   Moonrise Kingdom      2012.0   16000000.0   45507053.0
# 84    The Perks of Being a Wallflower      2012.0   13000000.0   17738570.0
# ...

# %%
df.head(8)
# Out:
#                    Title  title_year     budget      Gross  \
# 0             La La Land        2016   30000000  151101803
# 1               Zootopia        2016  150000000  341268248
# 2                   Lion        2016   12000000   51738905
# 3                Arrival        2016   47000000  100546139
# 4  Manchester by the Sea        2016    9000000   47695371
# 5     Hell or High Water        2016   12000000   27007844
# 6         Doctor Strange        2016  165000000  232641920
# 7                Tangled        2010  260000000  200807262
#
#            actor_1_name        actor_2_name     actor_3_name  \
# 0          Ryan Gosling          Emma Stone       Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman       Idris Elba
# 2             Dev Patel       Nicole Kidman      Rooney Mara
# 3             Amy Adams       Jeremy Renner  Forest Whitaker
# 4         Casey Affleck  Michelle Williams     Kyle Chandler
# 5            Chris Pine        Jeff Bridges       Ben Foster
# ...

# %%
#finding missing values in dataframe

# %%
df.isnull()
# Out:
#     Title  title_year  budget  Gross  actor_1_name  actor_2_name  \
# 0   False       False   False  False         False         False
# 1   False       False   False  False         False         False
# 2   False       False   False  False         False         False
# 3   False       False   False  False         False         False
# 4   False       False   False  False         False         False
# ..    ...         ...     ...    ...           ...           ...
# 95  False       False   False  False         False         False
# 96  False       False   False  False         False         False
# 97  False       False   False  False         False         False
# 98  False       False   False  False         False         False
# 99  False       False   False  False         False         False
#
#     actor_3_name  actor_1_facebook_likes  actor_2_facebook_likes  \
# 0          False                   False                   False
# ...

# %%
pd.options.display.max_columns=100
pd.options.display.max_rows=100

# %%
df.isnull().sum()
# Out:
# Title                      0
# title_year                 0
# budget                     0
# Gross                      0
# actor_1_name               0
# actor_2_name               0
# actor_3_name               0
# actor_1_facebook_likes     0
# actor_2_facebook_likes     1
# actor_3_facebook_likes     2
# IMDb_rating                0
# genre_1                    0
# genre_2                    3
# genre_3                   26
# MetaCritic                 5
# Runtime                    0
# CVotes10                   0
# CVotes09                   0
# CVotes08                   0
# CVotes07                   0
# CVotes06                   0
# CVotes05                   0
# CVotes04                   0
# CVotes03                   0
# CVotes02                   0
# CVotes01                   0
# CVotesMale                 0
# CVotesFemale               0
# CVotesU18                  0
# CVotesU18M                 0
# CVotesU18F                 0
# CVotes1829                 0
# ...

# %%
df.isnull().sum().sum()
# Out:
# 37

# %%
#missing value treatment

# %%
#let's import numpy as np

# %%
import numpy as np

# %%
df2 = df.fillna(value=0)
df2
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
df3 = df.fillna(method="pad") #padding
df3
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
df4 = df.fillna(method="bfill")
df4
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
df5 = df.fillna(method="pad", axis=1) #padding
df5
# Out:
#                                               Title title_year     budget  \
# 0                                        La La Land       2016   30000000
# 1                                          Zootopia       2016  150000000
# 2                                              Lion       2016   12000000
# 3                                           Arrival       2016   47000000
# 4                             Manchester by the Sea       2016    9000000
# 5                                Hell or High Water       2016   12000000
# 6                                    Doctor Strange       2016  165000000
# 7                                           Tangled       2010  260000000
# 8                             The Dark Knight Rises       2012  250000000
# 9                        Captain America: Civil War       2016  250000000
# 10              The Hobbit: The Desolation of Smaug       2013  225000000
# 11                                     The Avengers       2012  220000000
# ...

# %%
df5 = df.fillna(method="bfill", axis=1) #backfill
df5
# Out:
#                                               Title title_year     budget  \
# 0                                        La La Land       2016   30000000
# 1                                          Zootopia       2016  150000000
# 2                                              Lion       2016   12000000
# 3                                           Arrival       2016   47000000
# 4                             Manchester by the Sea       2016    9000000
# 5                                Hell or High Water       2016   12000000
# 6                                    Doctor Strange       2016  165000000
# 7                                           Tangled       2010  260000000
# 8                             The Dark Knight Rises       2012  250000000
# 9                        Captain America: Civil War       2016  250000000
# 10              The Hobbit: The Desolation of Smaug       2013  225000000
# 11                                     The Avengers       2012  220000000
# ...

# %%
df8=df.fillna({"actor_3_facebook_likes":2000,"actor_2_facebook_likes":5000})
df8
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
#task- fill the value of actor_3_facebook_likes for movies la la land and arrival as 5000 and 10000 respectively

# %%
df10 =df.fillna(value= df["actor_3_facebook_likes"].mean())
df10
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
#replacing the values

# %%
df11= df.replace(to_replace= "Lion", value= "Tiger")
df11
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                             Tiger        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
#second example
df12= df.replace(to_replace= 2016, value= 2017)
df12
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2017   30000000
# 1                                          Zootopia        2017  150000000
# 2                                              Lion        2017   12000000
# 3                                           Arrival        2017   47000000
# 4                             Manchester by the Sea        2017    9000000
# 5                                Hell or High Water        2017   12000000
# 6                                    Doctor Strange        2017  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2017  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
# task2- repalce the value of movie Doctor strange from 2016 to 2017

# %%
#creating new column by performing the opeartion in other column

# %%
df["profit"]= df["Gross"]-df["budget"]

# %%
df
# Out:
#                                               Title  title_year     budget  \
# 0                                        La La Land        2016   30000000
# 1                                          Zootopia        2016  150000000
# 2                                              Lion        2016   12000000
# 3                                           Arrival        2016   47000000
# 4                             Manchester by the Sea        2016    9000000
# 5                                Hell or High Water        2016   12000000
# 6                                    Doctor Strange        2016  165000000
# 7                                           Tangled        2010  260000000
# 8                             The Dark Knight Rises        2012  250000000
# 9                        Captain America: Civil War        2016  250000000
# 10              The Hobbit: The Desolation of Smaug        2013  225000000
# ...

# %%
df[["Title", "profit"]]
# Out:
#                                               Title     profit
# 0                                        La La Land  121101803
# 1                                          Zootopia  191268248
# 2                                              Lion   39738905
# 3                                           Arrival   53546139
# 4                             Manchester by the Sea   38695371
# 5                                Hell or High Water   15007844
# 6                                    Doctor Strange   67641920
# 7                                           Tangled  -59192738
# 8                             The Dark Knight Rises  198130642
# 9                        Captain America: Civil War  157197282
# 10              The Hobbit: The Desolation of Smaug   33355354
# 11                                     The Avengers  403279547
# 12                                      Toy Story 3  214984497
# 13                                          Skyfall  104360277
# ...

# %%
#task -3 
#search on how to merge two dataframes

# %%
#Drop null values

# %%
df13= df. dropna(how="any")
df14= df. dropna(how="all")

# %%
df13
# Out:
#                                            Title  title_year     budget  \
# 1                                       Zootopia        2016  150000000
# 5                             Hell or High Water        2016   12000000
# 7                                        Tangled        2010  260000000
# 9                     Captain America: Civil War        2016  250000000
# 12                                   Toy Story 3        2010  200000000
# 13                                       Skyfall        2012  200000000
# 14                    X-Men: Days of Future Past        2014  200000000
# 15                       Star Trek Into Darkness        2013  190000000
# 17                              Edge of Tomorrow        2014  178000000
# 18                                    Inside Out        2015  175000000
# 19                       Guardians of the Galaxy        2014  170000000
# 20           Captain America: The Winter Soldier        2014  170000000
# ...

# %% [markdown]
# ## Interpolate()

# %%
Let' say we have a df with values as
1
2
3
4
NaN
6
7
8
9
Interpolate functions will automatically interpolate this and add "5" in place of the missing value.
There are multiple fuctions available in it and this one is a linear function.
Let's say we have 3 values
5
NaN
6
this will automatically take the mean of these two numbers and fill "5.5" in between.
Interpolate will take the number previous and next to the missing value and then fill the data.

# %%
#"lets apply this on actor_2_facebook_likes column"
# df13=df # create a copy of our original database
# df13["actor_2_facebook_likes"]=df13["actor_2_facebook_likes"].interpolate(method="linear")

# %%
#task 4-search more abut interpolate method and its methods.
